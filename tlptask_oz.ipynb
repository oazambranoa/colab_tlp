# %% [markdown]
# <a href="https://colab.research.google.com/github/oazambranoa/colab_tlp/blob/main/tlptask_oz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Tarea Pandas Numpy
#
# Dataset usado: https://www.kaggle.com/datasets/chasewillden/linuxcommits?resource=download

# %%
df = pd.read_csv("sample_data/LinuxCommitData.csv", sep=",")
df
# Out:
#                       Date  commits  additions  deletions   userid  \
# 0      2005-01-09 00:00:00        1          1          1  7852154
# 1      2005-01-30 00:00:00        1          7          1   911239
# 2      2005-02-27 00:00:00        1         24         16   911239
# 3      2005-03-13 00:00:00        1          1          6   701714
# 4      2005-03-20 00:00:00        1          1          4  3358267
# ...                    ...      ...        ...        ...      ...
# 22367  2013-04-28 00:00:00      208        870       1846  2887953
# 22368  2012-11-18 00:00:00      211       3924       4135  2365013
# 22369  2011-05-08 00:00:00      215       4587       6453   884942
# 22370  2009-03-15 00:00:00      227      13817      13802  2365013
# 22371  2015-08-16 00:00:00      258      61128      58069  1425239
#
#        startofweek
# 0       1105228800
# 1       1107043200
# 2       1109462400
# 3       1110672000
# 4       1111276800
# ...            ...
# ...

# %% [markdown]
# # Visualización de la estructura

# %%
df.shape
# Out:
# (22372, 6)

# %%
df.dtypes
# Out:
# Date           object
# commits         int64
# additions       int64
# deletions       int64
# userid          int64
# startofweek     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'commits', 'additions', 'deletions', 'userid', 'startofweek'], dtype='object')

# %%
df.values
# Out:
# array([['2005-01-09 00:00:00', 1, 1, 1, 7852154, 1105228800],
#        ['2005-01-30 00:00:00', 1, 7, 1, 911239, 1107043200],
#        ['2005-02-27 00:00:00', 1, 24, 16, 911239, 1109462400],
#        ...,
#        ['2011-05-08 00:00:00', 215, 4587, 6453, 884942, 1304812800],
#        ['2009-03-15 00:00:00', 227, 13817, 13802, 2365013, 1237075200],
#        ['2015-08-16 00:00:00', 258, 61128, 58069, 1425239, 1439683200]],
#       dtype=object)

# %%
df.head()
# Out:
#                   Date  commits  additions  deletions   userid  startofweek
# 0  2005-01-09 00:00:00        1          1          1  7852154   1105228800
# 1  2005-01-30 00:00:00        1          7          1   911239   1107043200
# 2  2005-02-27 00:00:00        1         24         16   911239   1109462400
# 3  2005-03-13 00:00:00        1          1          6   701714   1110672000
# 4  2005-03-20 00:00:00        1          1          4  3358267   1111276800

# %%
df.head(100)
# Out:
#                    Date  commits  additions  deletions    userid  startofweek
# 0   2005-01-09 00:00:00        1          1          1   7852154   1105228800
# 1   2005-01-30 00:00:00        1          7          1    911239   1107043200
# 2   2005-02-27 00:00:00        1         24         16    911239   1109462400
# 3   2005-03-13 00:00:00        1          1          6    701714   1110672000
# 4   2005-03-20 00:00:00        1          1          4   3358267   1111276800
# ..                  ...      ...        ...        ...       ...          ...
# 95  2005-08-28 00:00:00        1        135        155   1039303   1125187200
# 96  2005-08-28 00:00:00        1        350        382    966572   1125187200
# 97  2005-09-04 00:00:00        1          0          3   1051723   1125792000
# 98  2005-09-04 00:00:00        1          1          1   7477136   1125792000
# 99  2005-09-04 00:00:00        1         12          1  22451301   1125792000
#
# [100 rows x 6 columns]

# %%
df.tail(n=10)
# Out:
#                       Date  commits  additions  deletions   userid  \
# 22362  2011-07-17 00:00:00      166       1346       1374  4006501
# 22363  2012-12-02 00:00:00      166       3828       3812  2365013
# 22364  2016-08-07 00:00:00      176       1426       1126   154697
# 22365  2014-07-13 00:00:00      180       2027       2722  1649185
# 22366  2005-11-13 00:00:00      184      28837      26364   306482
# 22367  2013-04-28 00:00:00      208        870       1846  2887953
# 22368  2012-11-18 00:00:00      211       3924       4135  2365013
# 22369  2011-05-08 00:00:00      215       4587       6453   884942
# 22370  2009-03-15 00:00:00      227      13817      13802  2365013
# 22371  2015-08-16 00:00:00      258      61128      58069  1425239
#
#        startofweek
# 22362   1310860800
# 22363   1354406400
# 22364   1470528000
# 22365   1405209600
# 22366   1131840000
# 22367   1367107200
# 22368   1353196800
# 22369   1304812800
# 22370   1237075200
# 22371   1439683200

# %%
df.head(n=-1000)
# Out:
#                       Date  commits  additions  deletions    userid  \
# 0      2005-01-09 00:00:00        1          1          1   7852154
# 1      2005-01-30 00:00:00        1          7          1    911239
# 2      2005-02-27 00:00:00        1         24         16    911239
# 3      2005-03-13 00:00:00        1          1          6    701714
# 4      2005-03-20 00:00:00        1          1          4   3358267
# ...                    ...      ...        ...        ...       ...
# 21367  2008-01-27 00:00:00       23       1390        497     19270
# 21368  2008-02-03 00:00:00       23        389        184    726426
# 21369  2008-02-24 00:00:00       23        186        166     27855
# 21370  2008-04-20 00:00:00       23       4943       4337  18151320
# 21371  2008-11-23 00:00:00       23        611        502    775844
#
#        startofweek
# 0       1105228800
# 1       1107043200
# 2       1109462400
# 3       1110672000
# 4       1111276800
# ...            ...
# ...

# %%
df.head(n=20).tail(n=5)
# Out:
#                    Date  commits  additions  deletions    userid  startofweek
# 15  2005-04-17 00:00:00        1         74          0  22451301   1113696000
# 16  2005-04-17 00:00:00        1       5220       4811    966572   1113696000
# 17  2005-04-24 00:00:00        1          2          2   1053866   1114300800
# 18  2005-04-24 00:00:00        1          2          2   1606439   1114300800
# 19  2005-04-24 00:00:00        1          3          3  22451301   1114300800

# %% [markdown]
# # Manejo de columnas

# %%
df.Date.head(n=10)
# Out:
# 0    2005-01-09 00:00:00
# 1    2005-01-30 00:00:00
# 2    2005-02-27 00:00:00
# 3    2005-03-13 00:00:00
# 4    2005-03-20 00:00:00
# 5    2005-03-20 00:00:00
# 6    2005-03-27 00:00:00
# 7    2005-03-27 00:00:00
# 8    2005-04-03 00:00:00
# 9    2005-04-03 00:00:00
# Name: Date, dtype: object

# %%
df['Date'].head()
# Out:
# 0    2005-01-09 00:00:00
# 1    2005-01-30 00:00:00
# 2    2005-02-27 00:00:00
# 3    2005-03-13 00:00:00
# 4    2005-03-20 00:00:00
# Name: Date, dtype: object

# %%
df[['Date', 'userid', 'startofweek' ]].head(n=10)
# Out:
#                   Date   userid  startofweek
# 0  2005-01-09 00:00:00  7852154   1105228800
# 1  2005-01-30 00:00:00   911239   1107043200
# 2  2005-02-27 00:00:00   911239   1109462400
# 3  2005-03-13 00:00:00   701714   1110672000
# 4  2005-03-20 00:00:00  3358267   1111276800
# 5  2005-03-20 00:00:00   306482   1111276800
# 6  2005-03-27 00:00:00  3358267   1111881600
# 7  2005-03-27 00:00:00  3979215   1111881600
# 8  2005-04-03 00:00:00  7852154   1112486400
# 9  2005-04-03 00:00:00   911239   1112486400

# %%
df.rename(columns={'userid': 'User Id'})
# Out:
#                       Date  commits  additions  deletions  User Id  \
# 0      2005-01-09 00:00:00        1          1          1  7852154
# 1      2005-01-30 00:00:00        1          7          1   911239
# 2      2005-02-27 00:00:00        1         24         16   911239
# 3      2005-03-13 00:00:00        1          1          6   701714
# 4      2005-03-20 00:00:00        1          1          4  3358267
# ...                    ...      ...        ...        ...      ...
# 22367  2013-04-28 00:00:00      208        870       1846  2887953
# 22368  2012-11-18 00:00:00      211       3924       4135  2365013
# 22369  2011-05-08 00:00:00      215       4587       6453   884942
# 22370  2009-03-15 00:00:00      227      13817      13802  2365013
# 22371  2015-08-16 00:00:00      258      61128      58069  1425239
#
#        startofweek
# 0       1105228800
# 1       1107043200
# 2       1109462400
# 3       1110672000
# 4       1111276800
# ...            ...
# ...

# %% [markdown]
# # Acceso a registros

# %%
df[594:600]
# Out:
#                     Date  commits  additions  deletions    userid  startofweek
# 594  2007-04-29 00:00:00        1          6          1     14953   1177804800
# 595  2007-04-29 00:00:00        1         13          1     19270   1177804800
# 596  2007-04-29 00:00:00        1         24          8  10671515   1177804800
# 597  2007-04-29 00:00:00        1         26         18    966572   1177804800
# 598  2007-04-29 00:00:00        1         56          1     57437   1177804800
# 599  2007-04-29 00:00:00        1        249        194   4498177   1177804800

# %%
df.iloc[894:903, [1,3,4]]
# Out:
#      commits  deletions    userid
# 894        1          4     41443
# 895        1         34   5159728
# 896        1         64  18151320
# 897        1          5    680946
# 898        1          0   1059722
# 899        1          3  22451301
# 900        1          3   1209359
# 901        1          1     41443
# 902        1          1   1042521

# %%
registros = [ 34, 653, 1928]
columnnas = ['commits', 'userid', 'additions']
df.loc[registros, columnnas]
# Out:
#       commits    userid  additions
# 34          1   7852154          5
# 653         1     54119          1
# 1928        1  17337792          9

# %% [markdown]
# # Eliminacion de registros

# %%
df.drop(2).head()
# Out:
#                   Date  commits  additions  deletions   userid  startofweek
# 0  2005-01-09 00:00:00        1          1          1  7852154   1105228800
# 1  2005-01-30 00:00:00        1          7          1   911239   1107043200
# 3  2005-03-13 00:00:00        1          1          6   701714   1110672000
# 4  2005-03-20 00:00:00        1          1          4  3358267   1111276800
# 5  2005-03-20 00:00:00        1          1          5   306482   1111276800

# %%
df.head()
# Out:
#                   Date  commits  additions  deletions   userid  startofweek
# 0  2005-01-09 00:00:00        1          1          1  7852154   1105228800
# 1  2005-01-30 00:00:00        1          7          1   911239   1107043200
# 2  2005-02-27 00:00:00        1         24         16   911239   1109462400
# 3  2005-03-13 00:00:00        1          1          6   701714   1110672000
# 4  2005-03-20 00:00:00        1          1          4  3358267   1111276800

# %% [markdown]
# # Eliminacion de columnas

# %%
df_copy = df.copy()
del df_copy['startofweek']
df_copy
# Out:
#                       Date  commits  additions  deletions   userid
# 0      2005-01-09 00:00:00        1          1          1  7852154
# 1      2005-01-30 00:00:00        1          7          1   911239
# 2      2005-02-27 00:00:00        1         24         16   911239
# 3      2005-03-13 00:00:00        1          1          6   701714
# 4      2005-03-20 00:00:00        1          1          4  3358267
# ...                    ...      ...        ...        ...      ...
# 22367  2013-04-28 00:00:00      208        870       1846  2887953
# 22368  2012-11-18 00:00:00      211       3924       4135  2365013
# 22369  2011-05-08 00:00:00      215       4587       6453   884942
# 22370  2009-03-15 00:00:00      227      13817      13802  2365013
# 22371  2015-08-16 00:00:00      258      61128      58069  1425239
#
# [22372 rows x 5 columns]

# %%
df
# Out:
#                       Date  commits  additions  deletions   userid  \
# 0      2005-01-09 00:00:00        1          1          1  7852154
# 1      2005-01-30 00:00:00        1          7          1   911239
# 2      2005-02-27 00:00:00        1         24         16   911239
# 3      2005-03-13 00:00:00        1          1          6   701714
# 4      2005-03-20 00:00:00        1          1          4  3358267
# ...                    ...      ...        ...        ...      ...
# 22367  2013-04-28 00:00:00      208        870       1846  2887953
# 22368  2012-11-18 00:00:00      211       3924       4135  2365013
# 22369  2011-05-08 00:00:00      215       4587       6453   884942
# 22370  2009-03-15 00:00:00      227      13817      13802  2365013
# 22371  2015-08-16 00:00:00      258      61128      58069  1425239
#
#        startofweek
# 0       1105228800
# 1       1107043200
# 2       1109462400
# 3       1110672000
# 4       1111276800
# ...            ...
# ...

# %% [markdown]
# # Manejo de indices

# %%
df = df.set_index('Date')
df.head()
# Out:
#                      commits  additions  deletions   userid  startofweek
# Date
# 2005-01-09 00:00:00        1          1          1  7852154   1105228800
# 2005-01-30 00:00:00        1          7          1   911239   1107043200
# 2005-02-27 00:00:00        1         24         16   911239   1109462400
# 2005-03-13 00:00:00        1          1          6   701714   1110672000
# 2005-03-20 00:00:00        1          1          4  3358267   1111276800

# %%
df = df.reset_index()
df.head()
# Out:
#                   Date  commits  additions  deletions   userid  startofweek
# 0  2005-01-09 00:00:00        1          1          1  7852154   1105228800
# 1  2005-01-30 00:00:00        1          7          1   911239   1107043200
# 2  2005-02-27 00:00:00        1         24         16   911239   1109462400
# 3  2005-03-13 00:00:00        1          1          6   701714   1110672000
# 4  2005-03-20 00:00:00        1          1          4  3358267   1111276800

# %% [markdown]
# # Modificacion de registros

# %%
df.dtypes
# Out:
# Date           object
# commits         int64
# additions       int64
# deletions       int64
# userid          int64
# startofweek     int64
# dtype: object

# %%
df['commits']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 22367    208
# 22368    211
# 22369    215
# 22370    227
# 22371    258
# Name: commits, Length: 22372, dtype: int64

# %%
df['commits'] = df['commits'] - 20
df['commits']
# Out:
# 0        -29
# 1        -29
# 2        -29
# 3        -29
# 4        -29
#         ...
# 22367    178
# 22368    181
# 22369    185
# 22370    197
# 22371    228
# Name: commits, Length: 22372, dtype: int64

# %%
df['commits'] = df['commits'] + 20
df['commits']
# Out:
# 0         -9
# 1         -9
# 2         -9
# 3         -9
# 4         -9
#         ...
# 22367    198
# 22368    201
# 22369    205
# 22370    217
# 22371    248
# Name: commits, Length: 22372, dtype: int64

# %%
df['userid'][0] = '3358267'
df
# Out:
# <ipython-input-49-e692096e48f1>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['userid'][0] = '3358267'
# <ipython-input-49-e692096e48f1>:1: SettingWithCopyWarning:
# ...

# %%
df = df.reset_index()
df.head()
# Out:
#    index                 Date  commits  additions  deletions   userid  \
# 0      0  2005-01-09 00:00:00       -9          1          1  3358267
# 1      1  2005-01-30 00:00:00       -9          7          1   911239
# 2      2  2005-02-27 00:00:00       -9         24         16   911239
# 3      3  2005-03-13 00:00:00       -9          1          6   701714
# 4      4  2005-03-20 00:00:00       -9          1          4  3358267
#
#    startofweek
# 0   1105228800
# 1   1107043200
# 2   1109462400
# 3   1110672000
# 4   1111276800

# %% [markdown]
# # Consultas

# %%
df['additions'] == 2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22367    False
# 22368    False
# 22369    False
# 22370    False
# 22371    False
# Name: additions, Length: 22372, dtype: bool

# %%
df[df['additions'] == 3]
# Out:
#        index                 Date  commits  additions  deletions    userid  \
# 7          7  2005-03-27 00:00:00       -9          3          0   3979215
# 19        19  2005-04-24 00:00:00       -9          3          3  22451301
# 54        54  2005-06-26 00:00:00       -9          3          5   1080275
# 65        65  2005-07-24 00:00:00       -9          3          0   1070153
# 76        76  2005-08-07 00:00:00       -9          3          0   5585575
# ...      ...                  ...      ...        ...        ...       ...
# 14607  14607  2013-02-17 00:00:00       -5          3         87   1080275
# 15065  15065  2016-08-07 00:00:00       -5          3          8  10477916
# 15534  15534  2011-02-27 00:00:00       -4          3        905   5613544
# 16019  16019  2015-05-24 00:00:00       -4          3         24    502938
# 21964  21964  2015-01-04 00:00:00       24          3        483    306482
#
#        startofweek
# 7       1111881600
# 19      1114300800
# ...

# %%
df[(df['additions'] == 5) | (df['additions'] == 6)]
# Out:
#        index                 Date  commits  additions  deletions   userid  \
# 9          9  2005-04-03 00:00:00       -9          5          2   911239
# 24        24  2005-05-01 00:00:00       -9          5          4  5585575
# 29        29  2005-05-15 00:00:00       -9          5          0  2183268
# 34        34  2005-05-22 00:00:00       -9          5          6  7852154
# 38        38  2005-05-29 00:00:00       -9          6          0  1606439
# ...      ...                  ...      ...        ...        ...      ...
# 16863  16863  2014-09-07 00:00:00       -3          5         88    32593
# 17268  17268  2010-01-31 00:00:00       -2          6         18   502938
# 18727  18727  2013-08-25 00:00:00        0          5      11742  1030448
# 20526  20526  2013-11-24 00:00:00        6          5         28  2887953
# 22108  22108  2013-10-20 00:00:00       32          6         77  2887953
#
#        startofweek
# 9       1112486400
# 24      1114905600
# ...

# %%
df[(df['additions'] == 5) & (df['commits'] > 2)]
# Out:
#        index                 Date  commits  additions  deletions   userid  \
# 20526  20526  2013-11-24 00:00:00        6          5         28  2887953
#
#        startofweek
# 20526   1385251200

# %%
df[(df['additions'] == 5) & (df['commits'] > 2)].count()
# Out:
# index          1
# Date           1
# commits        1
# additions      1
# deletions      1
# userid         1
# startofweek    1
# dtype: int64

# %%
df[(df['additions'] == 5) & (df['commits'] > 2)]['deletions'].count()
# Out:
# 1

# %% [markdown]
# # Eliminacion de NaN

# %%
df.shape
# Out:
# (22372, 7)

# %%
df.dropna()
# Out:
#        index                 Date  commits  additions  deletions   userid  \
# 0          0  2005-01-09 00:00:00       -9          1          1  3358267
# 1          1  2005-01-30 00:00:00       -9          7          1   911239
# 2          2  2005-02-27 00:00:00       -9         24         16   911239
# 3          3  2005-03-13 00:00:00       -9          1          6   701714
# 4          4  2005-03-20 00:00:00       -9          1          4  3358267
# ...      ...                  ...      ...        ...        ...      ...
# 22367  22367  2013-04-28 00:00:00      198        870       1846  2887953
# 22368  22368  2012-11-18 00:00:00      201       3924       4135  2365013
# 22369  22369  2011-05-08 00:00:00      205       4587       6453   884942
# 22370  22370  2009-03-15 00:00:00      217      13817      13802  2365013
# 22371  22371  2015-08-16 00:00:00      248      61128      58069  1425239
#
#        startofweek
# 0       1105228800
# 1       1107043200
# ...

# %%
df
# Out:
#        index                 Date  commits  additions  deletions   userid  \
# 0          0  2005-01-09 00:00:00       -9          1          1  3358267
# 1          1  2005-01-30 00:00:00       -9          7          1   911239
# 2          2  2005-02-27 00:00:00       -9         24         16   911239
# 3          3  2005-03-13 00:00:00       -9          1          6   701714
# 4          4  2005-03-20 00:00:00       -9          1          4  3358267
# ...      ...                  ...      ...        ...        ...      ...
# 22367  22367  2013-04-28 00:00:00      198        870       1846  2887953
# 22368  22368  2012-11-18 00:00:00      201       3924       4135  2365013
# 22369  22369  2011-05-08 00:00:00      205       4587       6453   884942
# 22370  22370  2009-03-15 00:00:00      217      13817      13802  2365013
# 22371  22371  2015-08-16 00:00:00      248      61128      58069  1425239
#
#        startofweek
# 0       1105228800
# 1       1107043200
# ...

# %%
additions = df[df['commits'] == 10]
additions
# Out:
#        index                 Date  commits  additions  deletions    userid  \
# 21033  21033  2005-08-14 00:00:00       10        685        368   1209359
# 21034  21034  2005-09-04 00:00:00       10       1357       1477    306482
# 21035  21035  2005-11-06 00:00:00       10        988       1306   1606439
# 21036  21036  2006-03-05 00:00:00       10         59        258   3358267
# 21037  21037  2006-04-09 00:00:00       10        124      28381   3358267
# ...      ...                  ...      ...        ...        ...       ...
# 21167  21167  2016-04-17 00:00:00       10        225        233  12929622
# 21168  21168  2016-07-10 00:00:00       10        434        187     19270
# 21169  21169  2016-09-04 00:00:00       10       3032       3900  22451301
# 21170  21170  2016-10-09 00:00:00       10        749        511    958432
# 21171  21171  2016-12-25 00:00:00       10        643        114     38832
#
#        startofweek
# 21033   1123977600
# 21034   1125792000
# ...

# %%
x= [int(i.split()[4]) for i in additions['commits']]

# %%
additions['commits'] = [int(i.split()[2]) for i in additions['commits']]
additions

# %%
additions.dtypes
# Out:
# index           int64
# Date           object
# commits         int64
# additions       int64
# deletions       int64
# userid         object
# startofweek     int64
# dtype: object

# %% [markdown]
# # numpy

# %%
import numpy as np
np.sum(additions['deletions'])
# Out:
# 134769

# %%
np.mean(additions['deletions'])
# Out:
# 969.5611510791367
